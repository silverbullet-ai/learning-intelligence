# %%
## array

import array

arr = array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
## math

import math

print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random

import random

print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 10
# apple

# %%
## os

import os

print(os.getcwd())
print(os.listdir('.'))
print(os.mkdir('new_directory'))
# Out:
# a:\Nexus\Coding\Data-Science-AI\learning-intelligence\02-python-core\05-modules-and-packages\02-standard-library-overview
# ['example.ipynb', 'sample']
# None

# %%
## shutil

import shutil
shutil.copy('sample/source_file.txt', 'sample/destination_file.txt')
# Out:
# 'sample/destination_file.txt'

# %%
## json

import json

data = {'name': 'Aahish', 'age': 23,}

json_string = json.dumps(data)
print(json_string)
print(type(json_string))

data_dict = json.loads(json_string)
print(data_dict)
print(type(data_dict))
# Out:
# {"name": "Aahish", "age": 23}
# <class 'str'>
# {'name': 'Aahish', 'age': 23}
# <class 'dict'>

# %%
## csv

import csv

with open('sample/data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age'])
    writer.writerow(['Aahish', 23])

with open('sample/data.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['Aahish', '23']

# %%
## datetime

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-05-13 22:07:14.748928
# 2026-05-12 22:07:14.748928

# %%
## time

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1778690234.767623
# 1778690236.7691858

# %%
## regular expressions

import re

pattern = r'\d+'
text = 'There are 3 cats and 4 dogs.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['3', '4']
