# %% [markdown]
# # Object Oriented Programming

# %%
## Class

class Car:
    pass

audi = Car()
bmw = Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)

# %%
print(bmw)

# %%
audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
tata = Car()
tata.doors = 4  # not the proper way to define attribute
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 tata = Car()
#       2 tata.doors = 4  # not the proper way to define attribute
# ----> 3 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
## Instance variable and methods

class Dog:
    ## constructor
    def __init__(self,name, age):
        self.name = name
        self.age = age


## create the object
dog1 = Dog('Spike', 7)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Spike
# 7

# %%
## Define a class with instance method

class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
    def bark(self):
        print(f'{self.name} says woof')

dog1 = Dog('Spike', 7)
dog1.bark()
# Out:
# Spike says woof

# %%
dog2 = Dog('Scooby Doo', 12)
dog2.bark()
# Out:
# Scooby Doo says woof

# %%
## Modeling a bank account

### class for bank account
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
        print(f'{amount} deposited in bank.\nAvailable Balance:{self.balance}')
    
    def withdraw(self, amount):
        if amount > self.balance:
            print('Insufficient funds!!!')
        else:
            self.balance -= amount
            print(f'{amount} withdrawn from bank.\nAvailable Balance:{self.balance}')
    
    def get_balance(self):
        return self.balance

### create an account

acc1 = BankAccount('Aahish', 23000)
print(acc1.balance)
# Out:
# 23000

# %%
### call instance mehtods

acc1.deposit(28000)
# Out:
# 28000 deposited in bank.
# Available Balance:51000

# %%
acc1.withdraw(7000)
# Out:
# 7000 withdrawn from bank.
# Available Balance:44000

# %%
print(acc1.get_balance())
# Out:
# 44000
