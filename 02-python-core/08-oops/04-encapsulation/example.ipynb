# %% [markdown]
# # Encapsulation

# %%
class Person:
    def __init__(self,name,age,gender):
        self.name = name        # public variable
        self.age = age          # public variable
        self.gender = gender    # public variable

def get_name(person):
    print(person.name)

person = Person('Aahish', 23, 'Male')
print(person.age)
get_name(person)
# Out:
# 23
# Aahish

# %%
dir(person)      # we can see 'name','age' and 'gender' variables in the directory as it is.
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'gender',
#  'name']

# %%
class Person:
    def __init__(self,name,age,gender):
        self.__name = name        # private variable
        self.__age = age          # private variable
        self.gender = gender      # public variable

def get_name(person):
    print(person.__name)

person = Person('Aahish', 23, 'Male')
print(person.gender)
print(person.__age)
get_name(person)
# Out:
# Male
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 12
#       8     print(person.__name)
#       9
#      10 person = Person('Aahish', 23, 'Male')
#      11 print(person.gender)
# ---> 12 print(person.__age)
#      13 get_name(person)
#
# AttributeError: 'Person' object has no attribute '__age'

# %%
dir(person)     # 'age' and 'name' variable is slightly changed.
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
print(person._Person__name)     # this is called 'name mangling'
# Out:
# Aahish

# %%
class Person:
    def __init__(self,name,age,gender):
        self._name = name        # protected varible
        self._age = age          # protected variable
        self.gender = gender     # public variable

class Employee(Person):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)

employee = Employee('Aahish', 23, 'Male')
print(employee._name)
# Out:
# Aahish

# %%
dir(employee)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age',
#  '_name',
#  'gender']

# %%
# Encapsulation with setter and getter method.

class Person:
    def __init__(self,name,age):
        self.__name = name
        self.__age = age
    
    ## setter method for name
    def set_name(self,name):
        self.__name = name
    
    ## getter method for name
    def get_name(self):
        return self.__name
    
    ## setter method for age
    def set_age(self,age):
        if age > 0:
            self.__age = age
        else:
            print('Age cannot be negative')
    
    ## getter method for age
    def get_age(self):
        return self.__age

person = Person('Aahish', 23)

## Access and modify private variables using setter and getter methods.
print(person.get_name())
print(person.get_age())

print()

person.set_name('Aayan')
person.set_age(22)
print(person.get_name())
print(person.get_age())

print()

person.set_age(-3)
# Out:
# Aahish
# 23
#
# Aayan
# 22
#
# Age cannot be negative
