# %%
name = "Aahish"
Name = "AI"

print(name)
print(Name)
# Out:
# Aahish
# AI

# %%
var = 10
print(type(var))

var = "Hello"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
if True:
    print("Correct indentation")

    if False:
        print("Won’t print")

    print("This will print")

print("Outside block")
# Out:
# Correct indentation
# This will print
# Outside block
