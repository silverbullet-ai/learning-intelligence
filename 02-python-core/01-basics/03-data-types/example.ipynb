# %%
a = 10
b = 5.5
c = "hello"
d = True

print(type(a), type(b), type(c), type(d))
# Out:
# Running cells with 'python-core (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p a:\Nexus\Coding\Data-Science-AI\learning-intelligence\envs\python-core ipykernel --update-deps --force-reinstall'
