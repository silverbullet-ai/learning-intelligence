# %%
## Program vs Process
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Discussion:
# - File on disk = Program
# - Running script = Process

# %%
## Current Process
import os

print(os.getpid())
# Out:
# 27480

# %% [markdown]
# ### Shows:
# - Every running program has a Process ID (PID)

# %%
## Active Thread
import threading

print(threading.current_thread().name)
# Out:
# MainThread

# %% [markdown]
# ### MainThreadShows:
# - Every Python program starts with at least one thread.

# %%
## Process and Thread Together
import os
import threading

print("Process ID:", os.getpid())
print("Thread Name:", threading.current_thread().name)
# Out:
# Process ID: 27480
# Thread Name: MainThread
