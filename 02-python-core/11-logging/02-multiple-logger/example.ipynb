# %% [markdown]
# # Multiple Logger

# %%
import logging

## create logger for module1
logger1 = logging.getLogger('module1')
logger1.setLevel(logging.DEBUG)

## create logger for module2
logger2 = logging.getLogger('module2')
logger2.setLevel(logging.WARNING)

## create basic config
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s|%(name)s|%(levelname)s|%(message)s',
    datefmt='%Y/%m/%d %H:%M:%S'
)

# %%
## logger message with different logger
logger1.debug('This is debug message for module1')
logger2.warning('This is warning message for module2')
logger2.debug('This is the debug message for module2')
# Out:
# 2026/06/17 19:05:49|module1|DEBUG|This is debug message for module1
# 2026/06/17 19:05:49|module2|WARNING|This is warning message for module2
